# %%
import requests
response = requests.get('https://fakestoreapi.com/products')
print(response.json())
# Out:
# [{'id': 1, 'title': 'Fjallraven - Foldsack No. 1 Backpack, Fits 15 Laptops', 'price': 109.95, 'description': 'Your perfect pack for everyday use and walks in the forest. Stash your laptop (up to 15 inches) in the padded sleeve, your everyday', 'category': "men's clothing", 'image': 'https://fakestoreapi.com/img/81fPKd-2AYL._AC_SL1500_t.png', 'rating': {'rate': 3.9, 'count': 120}}, {'id': 2, 'title': 'Mens Casual Premium Slim Fit T-Shirts ', 'price': 22.3, 'description': 'Slim-fitting style, contrast raglan long sleeve, three-button henley placket, light weight & soft fabric for breathable and comfortable wearing. And Solid stitched shirts with round neck made for durability and a great fit for casual fashion wear and diehard baseball fans. The Henley style round neckline includes a three-button placket.', 'category': "men's clothing", 'image': 'https://fakestoreapi.com/img/71-3HjGNDUL._AC_SY879._SX._UX._SY._UY_t.png', 'rating': {'rate': 4.1, 'count': 259}}, {'id': 3, 'title': 'Mens C
# ...

# %%
import pandas as pd

data = response.json()

df = pd.DataFrame(data)

df.head()
# Out:
#    id                                              title   price  \
# 0   1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1   2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2   3                                 Mens Cotton Jacket   55.99
# 3   4                               Mens Casual Slim Fit   15.99
# 4   5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
#
#                                          description        category  \
# 0  Your perfect pack for everyday use and walks i...  men's clothing
# 1  Slim-fitting style, contrast raglan long sleev...  men's clothing
# 2  great outerwear jackets for Spring/Autumn/Wint...  men's clothing
# 3  The color could be slightly different between ...  men's clothing
# 4  From our Legends Collection, the Naga was insp...        jewelery
#
#                                                image  \
# 0  https://fakestoreapi.com/img/81fPKd-2AYL._AC_S...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           20 non-null     int64
#  1   title        20 non-null     object
#  2   price        20 non-null     float64
#  3   description  20 non-null     object
#  4   category     20 non-null     object
#  5   image        20 non-null     object
#  6   rating       20 non-null     object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 1.2+ KB

# %%
df.drop(['image'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           20 non-null     int64
#  1   title        20 non-null     object
#  2   price        20 non-null     float64
#  3   description  20 non-null     object
#  4   category     20 non-null     object
#  5   rating       20 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.1+ KB

# %%
df
# Out:
#     id                                              title   price  \
# 0    1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1    2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2    3                                 Mens Cotton Jacket   55.99
# 3    4                               Mens Casual Slim Fit   15.99
# 4    5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
# 5    6                       Solid Gold Petite Micropave   168.00
# 6    7                         White Gold Plated Princess    9.99
# 7    8  Pierced Owl Rose Gold Plated Stainless Steel D...   10.99
# 8    9  WD 2TB Elements Portable External Hard Drive -...   64.00
# 9   10  SanDisk SSD PLUS 1TB Internal SSD - SATA III 6...  109.00
# 10  11  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# 11  12  WD 4TB Gaming Drive Works with Playstation 4 P...  114.00
# 12  13  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...  599.00
# ...

# %%
df['rating'].head()
# Out:
# 0    {'rate': 3.9, 'count': 120}
# 1    {'rate': 4.1, 'count': 259}
# 2    {'rate': 4.7, 'count': 500}
# 3    {'rate': 2.1, 'count': 430}
# 4    {'rate': 4.6, 'count': 400}
# Name: rating, dtype: object

# %%
import ast

# Convert string to dictionary if needed
df['rating'] = df['rating'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Separate the columns
df['rate'] = df['rating'].apply(lambda x: x['rate'] if isinstance(x, dict) else None)
df['count'] = df['rating'].apply(lambda x: x['count'] if isinstance(x, dict) else None)

# %%
df
# Out:
#     id                                              title   price  \
# 0    1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1    2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2    3                                 Mens Cotton Jacket   55.99
# 3    4                               Mens Casual Slim Fit   15.99
# 4    5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
# 5    6                       Solid Gold Petite Micropave   168.00
# 6    7                         White Gold Plated Princess    9.99
# 7    8  Pierced Owl Rose Gold Plated Stainless Steel D...   10.99
# 8    9  WD 2TB Elements Portable External Hard Drive -...   64.00
# 9   10  SanDisk SSD PLUS 1TB Internal SSD - SATA III 6...  109.00
# 10  11  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# 11  12  WD 4TB Gaming Drive Works with Playstation 4 P...  114.00
# 12  13  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...  599.00
# ...

# %%
df.drop(['rating'], axis=1, inplace=True)

# %%
df
# Out:
#     id                                              title   price  \
# 0    1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1    2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2    3                                 Mens Cotton Jacket   55.99
# 3    4                               Mens Casual Slim Fit   15.99
# 4    5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
# 5    6                       Solid Gold Petite Micropave   168.00
# 6    7                         White Gold Plated Princess    9.99
# 7    8  Pierced Owl Rose Gold Plated Stainless Steel D...   10.99
# 8    9  WD 2TB Elements Portable External Hard Drive -...   64.00
# 9   10  SanDisk SSD PLUS 1TB Internal SSD - SATA III 6...  109.00
# 10  11  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# 11  12  WD 4TB Gaming Drive Works with Playstation 4 P...  114.00
# 12  13  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...  599.00
# ...

# %%
df['count'] = df['count'].astype(int)
df['rate'] = df['rate'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           20 non-null     int64
#  1   title        20 non-null     object
#  2   price        20 non-null     float64
#  3   description  20 non-null     object
#  4   category     20 non-null     object
#  5   rate         20 non-null     float64
#  6   count        20 non-null     int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.2+ KB

# %%
df.shape
# Out:
# (20, 7)

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# id             0
# title          0
# price          0
# description    0
# category       0
# rate           0
# count          0
# dtype: int64

# %%
df_new = df[['count', 'rate', 'price']]

df_new.describe()
# Out:
#             count       rate       price
# count   20.000000  20.000000   20.000000
# mean   286.800000   3.560000  162.046000
# std    162.751538   0.961578  272.220532
# min     70.000000   1.900000    7.950000
# 25%    143.750000   2.900000   15.240000
# 50%    254.500000   3.700000   56.490000
# 75%    400.000000   4.525000  110.962500
# max    679.000000   4.800000  999.990000

# %%
df['category'].value_counts()
# Out:
# category
# women's clothing    6
# electronics         6
# jewelery            4
# men's clothing      4
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(df_new)

# %%
sns.heatmap(df_new.corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.barplot(x='category', y='price', data=df)
# Out:
# <Axes: xlabel='category', ylabel='price'>

# %%
plt.scatter(df['count'], df['price'], alpha=0.6)
plt.title('Price vs Rating Count')
plt.xlabel('Number of Ratings')
plt.ylabel('Price (R)')
plt.show()

# %%
df[df['category'] == 'electronics'].sort_values(by='price', ascending=False)
# Out:
#     id                                              title   price  \
# 13  14  Samsung 49-Inch CHG90 144Hz Curved Gaming Moni...  999.99
# 12  13  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...  599.00
# 11  12  WD 4TB Gaming Drive Works with Playstation 4 P...  114.00
# 9   10  SanDisk SSD PLUS 1TB Internal SSD - SATA III 6...  109.00
# 10  11  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# 8    9  WD 2TB Elements Portable External Hard Drive -...   64.00
#
#                                           description     category  rate  \
# 13  49 INCH SUPER ULTRAWIDE 32:9 CURVED GAMING MON...  electronics   2.2
# 12  21. 5 inches Full HD (1920 x 1080) widescreen ...  electronics   2.9
# 11  Expand your PS4 gaming experience, Play anywhe...  electronics   4.8
# 9   Easy upgrade for faster boot up, shutdown, app...  electronics   2.9
# 10  3D NAND flash are applied to deliver high tran...  electronics   4.8
# ...

# %%
df[df['category'] == "jewelery"].sort_values(by='price', ascending=False)
# Out:
#    id                                              title   price  \
# 4   5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
# 5   6                       Solid Gold Petite Micropave   168.00
# 7   8  Pierced Owl Rose Gold Plated Stainless Steel D...   10.99
# 6   7                         White Gold Plated Princess    9.99
#
#                                          description  category  rate  count
# 4  From our Legends Collection, the Naga was insp...  jewelery   4.6    400
# 5  Satisfaction Guaranteed. Return or exchange an...  jewelery   3.9     70
# 7  Rose Gold Plated Double Flared Tunnel Plug Ear...  jewelery   1.9    100
# 6  Classic Created Wedding Engagement Solitaire D...  jewelery   3.0    400

# %%
df[df['category'] == "men's clothing"].sort_values(by='price', ascending=False)
# Out:
#    id                                              title   price  \
# 0   1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 2   3                                 Mens Cotton Jacket   55.99
# 1   2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 3   4                               Mens Casual Slim Fit   15.99
#
#                                          description        category  rate  \
# 0  Your perfect pack for everyday use and walks i...  men's clothing   3.9
# 2  great outerwear jackets for Spring/Autumn/Wint...  men's clothing   4.7
# 1  Slim-fitting style, contrast raglan long sleev...  men's clothing   4.1
# 3  The color could be slightly different between ...  men's clothing   2.1
#
#    count
# 0    120
# 2    500
# 1    259
# 3    430

# %%
df4 = df[df['category'] == "women's clothing"].sort_values(by='price', ascending=False)

# %%
sns.barplot(x='count', y='price', data=df4)
# Out:
# <Axes: xlabel='count', ylabel='price'>

# %%
from pathlib import Path

# Absolute Windows path where you want to save the CSV
output_dir = Path(r'C:/Users/cash/Data_Analysis_Files/Csv Files')
output_dir.mkdir(parents=True, exist_ok=True)
csv_path = output_dir / 'products.csv'

# Write the CSV
df.to_csv(csv_path, index=False)

print(f"DataFrame successfully saved to: {csv_path.resolve()}")
# Out:
# DataFrame successfully saved to: C:\Users\cash\Data_Analysis_Files\Csv Files\products.csv
